# %%
import mlflow

mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
# 숫자를 제곱하는 간단한 함수 정의
def square_number(x):
    return x**2

# %%
# 1부터 10까지 숫자를 반복하여 MLflow로 실험 추적 수행
for x in range(1, 11) :
    # MLflow의 실험 기록을 시작 (각 숫자마다 새로운 Run 생성)
    # run_name으로 "square_1", "square_2", ..., "square_10" 등 이름 지정
    with mlflow.start_run(run_name=f"square_{x}"):
        result = square_number(x)  # 현재 숫자를 제곱하여 결과 계산
        mlflow.log_param("inpu_number", x)   # 현재 입력한 숫자(x)를 MLflow 파라미터로 기록
        mlflow.log_metric("square_result", result)  # 제곱한 결과를 MLflow 메트릭으로 기록
# Out:
# 🏃 View run square_1 at: http://127.0.0.1:5000/#/experiments/0/runs/0b1ef7b153104fcab05f575209fb0df6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0
# 🏃 View run square_2 at: http://127.0.0.1:5000/#/experiments/0/runs/f56be861031e4fd583f6566e8cd2c4a1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0
# 🏃 View run square_3 at: http://127.0.0.1:5000/#/experiments/0/runs/967d50ef21e74c60ac5027dd683cbdea
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0
# 🏃 View run square_4 at: http://127.0.0.1:5000/#/experiments/0/runs/c6cdabadd75b4718978b7d9c8c4af247
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0
# 🏃 View run square_5 at: http://127.0.0.1:5000/#/experiments/0/runs/69c3934f8e4848b4a77daf94a2561575
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0
# 🏃 View run square_6 at: http://127.0.0.1:5000/#/experiments/0/runs/977ec9c4303d41108917484eb17e9dac
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0
# 🏃 View run square_7 at: http://127.0.0.1:5000/#/experiments/0/runs/672963d15d1344e9a3321ec87e3027a8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0
# 🏃 View run square_8 at: http://127.0.0.1:5000/#/experiments/0/runs/be99c016525d4518a86fc8cb3784054d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0
# 🏃 View run square_9 at: http://127.0.0.1:5000/#/experiments/0/runs/e05de2660c79403ab85230ca3ed2cd73
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0
# 🏃 View run square_10 at: http://127.0.0.1:5000/#/experiments/0/runs/bbff01298b5e4847b9d01c2bcf218fe3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0
