# %%
import mlflow

mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("my_first_experiment") # 원하는 실험명을 작성
# Out:
# 2026/04/21 17:04:28 INFO mlflow.tracking.fluent: Experiment with name 'my_first_experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///C:/Users/SSAFY/Desktop/TIL/09_data_analysis/g_mlflow/mlruns/3', creation_time=1776758668119, experiment_id='3', last_update_time=1776758668119, lifecycle_stage='active', name='my_first_experiment', tags={}>

# %%
accuracy = [0.85, 0.88, 1.0, 0.9, 0.85]

for i in range(5): 
    with mlflow.start_run():
        mlflow.log_param("pram1", i+1)
        mlflow.log_metric("accuracy", accuracy[i])
# Out:
# 🏃 View run upbeat-conch-495 at: http://127.0.0.1:5000/#/experiments/3/runs/74c13a0d12fb4c5a86b3009ebb77d5af
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
# 🏃 View run blushing-sloth-395 at: http://127.0.0.1:5000/#/experiments/3/runs/7b5ca75863384c72a1d4a2133dbc7f8b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
# 🏃 View run secretive-hare-81 at: http://127.0.0.1:5000/#/experiments/3/runs/da00792bf28240fe85d4da5e13a76859
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
# 🏃 View run magnificent-roo-960 at: http://127.0.0.1:5000/#/experiments/3/runs/3d44e7f8fc084aab91a0d0fecd85cc92
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
# 🏃 View run judicious-perch-562 at: http://127.0.0.1:5000/#/experiments/3/runs/5f06be2480974b738c27c64d5fcfc9d5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
